# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset1 = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/AAPL_historical_data.csv')

# %%
dataset1.shape
# Out:
# (10998, 9)

# %%
# Create the 'stock' column and fill it with the value 'Apple'
dataset1['stock'] = 'Apple'

# %%
dataset1.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset1['stock'].unique())
# Out:
# ['Apple']

# %%
dataset1.head(100)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume  \
# 0   1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1   1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2   1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3   1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4   1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
# ..         ...       ...       ...       ...       ...        ...        ...
# 95  1981-04-30  0.126674  0.127790  0.126674  0.126674   0.097653   12611200
# 96  1981-05-01  0.126674  0.127790  0.126674  0.126674   0.097653   16553600
# 97  1981-05-04  0.126674  0.126674  0.126116  0.126116   0.097223   14448000
# 98  1981-05-05  0.126116  0.126116  0.125558  0.125558   0.096792   17539200
# 99  1981-05-06  0.122768  0.122768  0.122210  0.122210   0.094211   18950400
#
#     Dividends  Stock Splits  stock
# ...

# %%
dataset1['Date'] = pd.to_datetime(dataset1['Date'], format='%Y-%m-%d')

# %%
dataset1['Date'] = dataset1['Date'].dt.strftime('%Y-%m-%d')

# %%
dataset1.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
# 5  1980-12-19  0.126116  0.126674  0.126116  0.126116   0.097223   48630400
# 6  1980-12-22  0.132254  0.132813  0.132254  0.132254   0.101954   37363200
# 7  1980-12-23  0.137835  0.138393  0.137835  0.137835   0.106257   46950400
# 8  1980-12-24  0.145089  0.145647  0.145089  0.145089   0.111849   48003200
# 9  1980-12-26  0.158482  0.159040  0.158482  0.158482   0.122173   55574400
#
#    Dividends  Stock Splits  stock
# 0        0.0           0.0  Apple
# 1        0.0           0.0  Apple
# ...

# %%
dataset2 = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/AMZN_historical_data.csv')

# %%
dataset2.shape
# Out:
# (6846, 9)

# %%
# Create the 'stock' column and fill it with the value 'Apple'
dataset2['stock'] = 'Amzn'

# %%
dataset2.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset2['stock'].unique())
# Out:
# ['Amzn']

# %%
dataset2.head(100)
# Out:
#           Date      Open      High       Low     Close  Adj Close      Volume  \
# 0   1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1   1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 2   1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 3   1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 4   1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000
# ..         ...       ...       ...       ...       ...        ...         ...
# 95  1997-09-30  0.200000  0.217448  0.190104  0.216927   0.216927   105096000
# 96  1997-10-01  0.221875  0.225000  0.196875  0.201042   0.201042    99984000
# 97  1997-10-02  0.202083  0.208854  0.199479  0.200521   0.200521    37536000
# 98  1997-10-03  0.204167  0.206250  0.198958  0.200781   0.200781    23280000
# 99  1997-10-06  0.200000  0.206250  0.197135  0.206250   0.206250    40560000
#
# ...

# %%
dataset2['Date'] = pd.to_datetime(dataset2['Date'], format='%Y-%m-%d')

# %%
dataset2['Date'] = dataset2['Date'].dt.strftime('%Y-%m-%d')

# %%
dataset2.head(100)
# Out:
#           Date      Open      High       Low     Close  Adj Close      Volume  \
# 0   1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1   1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 2   1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 3   1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 4   1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000
# ..         ...       ...       ...       ...       ...        ...         ...
# 95  1997-09-30  0.200000  0.217448  0.190104  0.216927   0.216927   105096000
# 96  1997-10-01  0.221875  0.225000  0.196875  0.201042   0.201042    99984000
# 97  1997-10-02  0.202083  0.208854  0.199479  0.200521   0.200521    37536000
# 98  1997-10-03  0.204167  0.206250  0.198958  0.200781   0.200781    23280000
# 99  1997-10-06  0.200000  0.206250  0.197135  0.206250   0.206250    40560000
#
# ...

# %%
dataset3 = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/GOOG_historical_data.csv')

# %%
dataset3.shape
# Out:
# (5020, 9)

# %%
# Create the 'stock' column and fill it with the value 'Apple'
dataset3['stock'] = 'Google'

# %%
dataset3.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset3['stock'].unique())
# Out:
# ['Google']

# %%
dataset3.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
# 5  2004-08-26  2.613952  2.688672  2.606729  2.687676   2.684621  142572401
# 6  2004-08-27  2.692408  2.705360  2.632383  2.643840   2.640835  124826132
# 7  2004-08-30  2.622171  2.627402  2.540727  2.540727   2.537839  104429967
# 8  2004-08-31  2.547950  2.583068  2.544463  2.549693   2.546795   98825037
# 9  2004-09-01  2.557912  2.564637  2.482445  2.496891   2.494053  183633734
#
#    Dividends  Stock Splits   stock
# 0        0.0           0.0  Google
# 1        0.0           0.0  Google
# ...

# %%
dataset3['Date'] = pd.to_datetime(dataset3['Date'], format='%Y-%m-%d')

# %%
dataset3['Date'] = dataset3['Date'].dt.strftime('%Y-%m-%d')

# %%
dataset3.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
# 5  2004-08-26  2.613952  2.688672  2.606729  2.687676   2.684621  142572401
# 6  2004-08-27  2.692408  2.705360  2.632383  2.643840   2.640835  124826132
# 7  2004-08-30  2.622171  2.627402  2.540727  2.540727   2.537839  104429967
# 8  2004-08-31  2.547950  2.583068  2.544463  2.549693   2.546795   98825037
# 9  2004-09-01  2.557912  2.564637  2.482445  2.496891   2.494053  183633734
#
#    Dividends  Stock Splits   stock
# 0        0.0           0.0  Google
# 1        0.0           0.0  Google
# ...

# %%
dataset4 = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/META_historical_data.csv')

# %%
dataset4.shape
# Out:
# (2926, 9)

# %%
# Create the 'stock' column and fill it with the value 'Apple'
dataset4['stock'] = 'Meta'

# %%
dataset4.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset4['stock'].unique())
# Out:
# ['Meta']

# %%
dataset4.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2012-12-12  28.000000  28.139999  27.370001  27.580000  27.523441
# 1  2012-12-13  27.590000  28.750000  27.430000  28.240000  28.182087
# 2  2012-12-14  28.180000  28.330000  26.760000  26.809999  26.755020
# 3  2012-12-17  26.770000  27.000000  26.320000  26.750000  26.695143
# 4  2012-12-18  26.959999  27.910000  26.900000  27.709999  27.653173
# 5  2012-12-19  27.830000  28.219999  26.950001  27.410000  27.353790
# 6  2012-12-20  27.490000  27.600000  27.129999  27.360001  27.303892
# 7  2012-12-21  26.660000  27.010000  26.120001  26.260000  26.206148
# 8  2012-12-24  26.500000  26.959999  26.200001  26.930000  26.874775
# 9  2012-12-26  27.030001  27.180000  26.379999  26.510000  26.455635
#
#      Volume  Dividends  Stock Splits stock
# 0  46704200        0.0           0.0  Meta
# 1  81051600        0.0           0.0  Meta
# 2  91631600        0.0           0.0  Meta
# ...

# %%
dataset4['Date'] = pd.to_datetime(dataset4['Date'], format='%Y-%m-%d')

# %%
dataset4['Date'] = dataset4['Date'].dt.strftime('%Y-%m-%d')

# %%
dataset4.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2012-12-12  28.000000  28.139999  27.370001  27.580000  27.523441
# 1  2012-12-13  27.590000  28.750000  27.430000  28.240000  28.182087
# 2  2012-12-14  28.180000  28.330000  26.760000  26.809999  26.755020
# 3  2012-12-17  26.770000  27.000000  26.320000  26.750000  26.695143
# 4  2012-12-18  26.959999  27.910000  26.900000  27.709999  27.653173
# 5  2012-12-19  27.830000  28.219999  26.950001  27.410000  27.353790
# 6  2012-12-20  27.490000  27.600000  27.129999  27.360001  27.303892
# 7  2012-12-21  26.660000  27.010000  26.120001  26.260000  26.206148
# 8  2012-12-24  26.500000  26.959999  26.200001  26.930000  26.874775
# 9  2012-12-26  27.030001  27.180000  26.379999  26.510000  26.455635
#
#      Volume  Dividends  Stock Splits stock
# 0  46704200        0.0           0.0  Meta
# 1  81051600        0.0           0.0  Meta
# 2  91631600        0.0           0.0  Meta
# ...

# %%
dataset5 = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/MSFT_historical_data.csv')

# %%
dataset5.shape
# Out:
# (9672, 9)

# %%
# Create the 'stock' column and fill it with the value 'Apple'
dataset5['stock'] = 'Msft'

# %%
dataset5.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset5['stock'].unique())
# Out:
# ['Msft']

# %%
dataset5.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume  \
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059946  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062087   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063158   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061552    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060482    47894400
# 5  1986-03-20  0.098090  0.098090  0.094618  0.095486   0.058876    58435200
# 6  1986-03-21  0.095486  0.097222  0.091146  0.092882   0.057270    59990400
# 7  1986-03-24  0.092882  0.092882  0.089410  0.090278   0.055665    65289600
# 8  1986-03-25  0.090278  0.092014  0.089410  0.092014   0.056735    32083200
# 9  1986-03-26  0.092014  0.095486  0.091146  0.094618   0.058341    22752000
#
#    Dividends  Stock Splits stock
# 0        0.0           0.0  Msft
# 1        0.0           0.0  Msft
# ...

# %%
dataset5['Date'] = pd.to_datetime(dataset5['Date'], format='%Y-%m-%d')

# %%
dataset5['Date'] = dataset5['Date'].dt.strftime('%Y-%m-%d')

# %%
dataset5.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume  \
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059946  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062087   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063158   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061552    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060482    47894400
# 5  1986-03-20  0.098090  0.098090  0.094618  0.095486   0.058876    58435200
# 6  1986-03-21  0.095486  0.097222  0.091146  0.092882   0.057270    59990400
# 7  1986-03-24  0.092882  0.092882  0.089410  0.090278   0.055665    65289600
# 8  1986-03-25  0.090278  0.092014  0.089410  0.092014   0.056735    32083200
# 9  1986-03-26  0.092014  0.095486  0.091146  0.094618   0.058341    22752000
#
#    Dividends  Stock Splits stock
# 0        0.0           0.0  Msft
# 1        0.0           0.0  Msft
# ...

# %%
dataset6 = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/NVDA_historical_data.csv')

# %%
dataset6.shape
# Out:
# (6421, 9)

# %%
# Create the 'stock' column and fill it with the value 'Apple'
dataset6['stock'] = 'Nvidia'

# %%
dataset6.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset6['stock'].unique())
# Out:
# ['Nvidia']

# %%
dataset6.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume  \
# 0  1999-01-22  0.043750  0.048828  0.038802  0.041016   0.037621  2714688000
# 1  1999-01-25  0.044271  0.045833  0.041016  0.045313   0.041562   510480000
# 2  1999-01-26  0.045833  0.046745  0.041146  0.041797   0.038337   343200000
# 3  1999-01-27  0.041927  0.042969  0.039583  0.041667   0.038218   244368000
# 4  1999-01-28  0.041667  0.041927  0.041276  0.041536   0.038098   227520000
# 5  1999-01-29  0.041536  0.041667  0.039583  0.039583   0.036307   244032000
# 6  1999-02-01  0.039583  0.040625  0.039583  0.040365   0.037024   154704000
# 7  1999-02-02  0.039583  0.040625  0.036068  0.037240   0.034158   264096000
# 8  1999-02-03  0.036719  0.038542  0.036458  0.038021   0.034874    75120000
# 9  1999-02-04  0.038542  0.041146  0.038021  0.040104   0.036784   181920000
#
#    Dividends  Stock Splits   stock
# 0        0.0           0.0  Nvidia
# 1        0.0           0.0  Nvidia
# ...

# %%
dataset6['Date'] = pd.to_datetime(dataset6['Date'], format='%Y-%m-%d')

# %%
dataset6['Date'] = dataset6['Date'].dt.strftime('%Y-%m-%d')

# %%
dataset6.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume  \
# 0  1999-01-22  0.043750  0.048828  0.038802  0.041016   0.037621  2714688000
# 1  1999-01-25  0.044271  0.045833  0.041016  0.045313   0.041562   510480000
# 2  1999-01-26  0.045833  0.046745  0.041146  0.041797   0.038337   343200000
# 3  1999-01-27  0.041927  0.042969  0.039583  0.041667   0.038218   244368000
# 4  1999-01-28  0.041667  0.041927  0.041276  0.041536   0.038098   227520000
# 5  1999-01-29  0.041536  0.041667  0.039583  0.039583   0.036307   244032000
# 6  1999-02-01  0.039583  0.040625  0.039583  0.040365   0.037024   154704000
# 7  1999-02-02  0.039583  0.040625  0.036068  0.037240   0.034158   264096000
# 8  1999-02-03  0.036719  0.038542  0.036458  0.038021   0.034874    75120000
# 9  1999-02-04  0.038542  0.041146  0.038021  0.040104   0.036784   181920000
#
#    Dividends  Stock Splits   stock
# 0        0.0           0.0  Nvidia
# 1        0.0           0.0  Nvidia
# ...

# %%
dataset7 = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/TSLA_historical_data.csv')

# %%
dataset7.shape
# Out:
# (3545, 9)

# %%
# Create the 'stock' column and fill it with the value 'Apple'
dataset7['stock'] = 'Tsla'

# %%
dataset7.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset7['stock'].unique())
# Out:
# ['Tsla']

# %%
dataset7.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1  2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2  2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3  2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4  2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 5  2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 6  2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 7  2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 8  2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 9  2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
#
#    Dividends  Stock Splits stock
# 0        0.0           0.0  Tsla
# 1        0.0           0.0  Tsla
# ...

# %%
dataset7['Date'] = pd.to_datetime(dataset7['Date'], format='%Y-%m-%d')

# %%
dataset7['Date'] = dataset7['Date'].dt.strftime('%Y-%m-%d')

# %%
dataset7.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1  2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2  2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3  2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4  2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 5  2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 6  2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 7  2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 8  2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 9  2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
#
#    Dividends  Stock Splits stock
# 0        0.0           0.0  Tsla
# 1        0.0           0.0  Tsla
# ...

# %%
# Concatenate the dataframes vertically
Dataset = pd.concat([dataset1,dataset2,dataset3,dataset4,dataset5,dataset6,dataset7], axis=0)

# %%
# Reset the index after concatenation
Dataset.reset_index(drop=True, inplace=True)

# %%
# Save the concatenated data to a new CSV file
Dataset.to_csv('/home/sanoy/Documents/kifiya-week-1/data/Concatenated_Data.csv', index=False)

# %%
dataset = pd.read_csv('/home/sanoy/Documents/kifiya-week-1/data/Concatenated_Data.csv')

# %%
dataset.shape
# Out:
# (45428, 10)

# %%
dataset.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock'],
#       dtype='object')

# %%
print(dataset['stock'].unique())
# Out:
# ['Apple' 'Amzn' 'Google' 'Meta' 'Msft' 'Nvidia' 'Tsla']

# %%
dataset.head(100)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume  \
# 0   1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1   1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2   1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3   1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4   1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
# ..         ...       ...       ...       ...       ...        ...        ...
# 95  1981-04-30  0.126674  0.127790  0.126674  0.126674   0.097653   12611200
# 96  1981-05-01  0.126674  0.127790  0.126674  0.126674   0.097653   16553600
# 97  1981-05-04  0.126674  0.126674  0.126116  0.126116   0.097223   14448000
# 98  1981-05-05  0.126116  0.126116  0.125558  0.125558   0.096792   17539200
# 99  1981-05-06  0.122768  0.122768  0.122210  0.122210   0.094211   18950400
#
#     Dividends  Stock Splits  stock
# ...

# %%
# Display the data types of all the feature
dataset.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Adj Close       float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# stock            object
# dtype: object

# %%
# To show the statistical descriptions of the whole dataset 
# Basic Statistics Summary
summary_stats=dataset.describe()

# %%
# Print the basic statistics
print("Basic Statistics Summary:")
print(summary_stats)
# Out:
# Basic Statistics Summary:
#                Open          High           Low         Close     Adj Close  \
# count  45428.000000  45428.000000  45428.000000  45428.000000  45428.000000
# mean      46.798370     47.397792     46.190101     46.810590     45.367891
# std       78.259474     79.277620     77.218532     78.274673     78.049554
# min        0.034896      0.035547      0.033333      0.034115      0.031291
# 25%        0.690500      0.708000      0.673541      0.693604      0.585204
# 50%       13.646101     13.827710     13.463250     13.644750     13.076301
# 75%       47.242501     47.720626     46.628125     47.193626     44.768961
# max      542.349976    542.809998    528.359985    539.909973    539.909973
#
#              Volume     Dividends  Stock Splits
# count  4.542800e+04  45428.000000  45428.000000
# mean   2.177785e+08      0.000847      0.002499
# std    3.076645e+08      0.022527      0.155291
# min    0.000000e+00      0.000000      0.000000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45428 entries, 0 to 45427
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          45428 non-null  object
#  1   Open          45428 non-null  float64
#  2   High          45428 non-null  float64
#  3   Low           45428 non-null  float64
#  4   Close         45428 non-null  float64
#  5   Adj Close     45428 non-null  float64
#  6   Volume        45428 non-null  int64
#  7   Dividends     45428 non-null  float64
#  8   Stock Splits  45428 non-null  float64
#  9   stock         45428 non-null  object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 3.5+ MB

# %%
#check the missing values of the dataset
dataset.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# stock           0
# dtype: int64

# %%
# To show the duplicated records
dataset.duplicated().sum()
# Out:
# 0

# %%
# Convert the Date column to datetime format for better handling
dataset['Date'] = pd.to_datetime(dataset['Date'])

# %%
dataset['stock'].value_counts()
# Out:
# stock
# Apple     10998
# Msft       9672
# Amzn       6846
# Nvidia     6421
# Google     5020
# Tsla       3545
# Meta       2926
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='stock', data=dataset)
plt.title('Count of Stock type')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Open', y='Close', hue='stock', data=dataset)
plt.title('Scatter Plot of Open vs Close Prices')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='stock', y='Close', data=dataset)
plt.title('Boxplot of Closing Prices by Stock Type')
plt.show()

# %%
# Plot the closing price over time
plt.plot(dataset['Date'], dataset['Close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Stock Price Over Time')
plt.show()

# %%
daily_prices = dataset.groupby('Date')[['Open', 'Close', 'High', 'Low']].mean()
daily_prices.plot(figsize=(10, 6), title='Daily Price Movements')
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
daily_prices = dataset.groupby('Date')[['Open']].mean()
daily_prices.plot(figsize=(10, 6), title='Daily Price Movements')
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
daily_prices = dataset.groupby('Date')[['Close']].mean()
daily_prices.plot(figsize=(10, 6), title='Daily Price Movements')
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
daily_prices = dataset.groupby('Date')[['High']].mean()
daily_prices.plot(figsize=(10, 6), title='Daily Price Movements')
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
daily_prices = dataset.groupby('Date')[['Low']].mean()
daily_prices.plot(figsize=(10, 6), title='Daily Price Movements')
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Close', hue='stock', data=dataset)
plt.title('Line Plot of Closing Prices Over Time')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Open', hue='stock', data=dataset)
plt.title('Line Plot of Opening Prices Over Time')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='High', hue='stock', data=dataset)
plt.title('Line Plot of High Prices Over Time')
plt.show()

# %%
# Get unique stock names
stocks = dataset['stock'].unique()

# Define a color list for each stock (you can customize these colors)
colors = ['blue', 'green', 'red', 'orange', 'purple', 'brown']  # Add more colors if needed

# Plot the closing price over time for each stock
for i, stock in enumerate(stocks):
    stock_data = dataset[dataset['stock'] == stock]
    plt.plot(stock_data['Date'], stock_data['Close'], label=stock, color=colors[i % len(colors)])

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Stock Price Over Time')
plt.legend()  # Show the legend to distinguish the stocks
plt.show()

# %%
# Get unique stock names
stocks = dataset['stock'].unique()
colors = ['blue', 'green', 'red', 'orange', 'purple', 'brown']  # Add more colors if needed
for i, stock in enumerate(stocks):
    stock_data = dataset[dataset['stock'] == stock]
    plt.plot(stock_data['Date'], stock_data['Open'], label=stock, color=colors[i % len(colors)])

plt.xlabel('Date')
plt.ylabel('Opening Price')
plt.title('Stock Price Over Time')
plt.legend()  # Show the legend to distinguish the stocks
plt.show()

# %%
# Volume Analysis
plt.figure(figsize=(14, 7))
plt.plot(dataset['Date'], dataset['Volume'], label='Volume', color='purple')
plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
# Correlation Matrix
corr_matrix = dataset[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].corr()

# Heatmap of correlations
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Stock Attributes')
plt.show()

# %%
# Select only numeric columns for correlation
numeric_df = dataset.select_dtypes(include=['float64', 'int64'])
# Plot correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Talib Analysis

# %%
import talib
import yfinance as yf

# %%
# ?talib.AROON
# Out:
# Signature: talib.AROON(high, low, timeperiod=-2147483648)
# Docstring:
# AROON(high, low[, timeperiod=?])
#
# Aroon (Momentum Indicators)
#
# Inputs:
#     prices: ['high', 'low']
# Parameters:
#     timeperiod: 14
# Outputs:
#     aroondown
#     aroonup
# Type:      function

# %%
dir(talib)
# Out:
# ['ACOS',
#  'AD',
#  'ADD',
#  'ADOSC',
#  'ADX',
#  'ADXR',
#  'APO',
#  'AROON',
#  'AROONOSC',
#  'ASIN',
#  'ATAN',
#  'ATR',
#  'AVGPRICE',
#  'BBANDS',
#  'BETA',
#  'BOP',
#  'CCI',
#  'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
#  'CDL3LINESTRIKE',
#  'CDL3OUTSIDE',
#  'CDL3STARSINSOUTH',
#  'CDL3WHITESOLDIERS',
#  'CDLABANDONEDBABY',
#  'CDLADVANCEBLOCK',
#  'CDLBELTHOLD',
#  'CDLBREAKAWAY',
#  'CDLCLOSINGMARUBOZU',
#  'CDLCONCEALBABYSWALL',
#  'CDLCOUNTERATTACK',
#  'CDLDARKCLOUDCOVER',
#  'CDLDOJI',
#  'CDLDOJISTAR',
#  'CDLDRAGONFLYDOJI',
#  'CDLENGULFING',
#  'CDLEVENINGDOJISTAR',
#  'CDLEVENINGSTAR',
#  'CDLGAPSIDESIDEWHITE',
#  'CDLGRAVESTONEDOJI',
#  'CDLHAMMER',
#  'CDLHANGINGMAN',
#  'CDLHARAMI',
#  'CDLHARAMICROSS',
#  'CDLHIGHWAVE',
#  'CDLHIKKAKE',
#  'CDLHIKKAKEMOD',
#  'CDLHOMINGPIGEON',
#  'CDLIDENTICAL3CROWS',
#  'CDLINNECK',
#  'CDLINVERTEDHAMMER',
#  'CDLKICKING',
#  'CDLKICKINGBYLENGTH',
#  'CDLLADDERBOTTOM',
#  'CDLLONGLEGGEDDOJI',
# ...

# %%
talib.get_functions()
# Out:
# ['HT_DCPERIOD',
#  'HT_DCPHASE',
#  'HT_PHASOR',
#  'HT_SINE',
#  'HT_TRENDMODE',
#  'ADD',
#  'DIV',
#  'MAX',
#  'MAXINDEX',
#  'MIN',
#  'MININDEX',
#  'MINMAX',
#  'MINMAXINDEX',
#  'MULT',
#  'SUB',
#  'SUM',
#  'ACOS',
#  'ASIN',
#  'ATAN',
#  'CEIL',
#  'COS',
#  'COSH',
#  'EXP',
#  'FLOOR',
#  'LN',
#  'LOG10',
#  'SIN',
#  'SINH',
#  'SQRT',
#  'TAN',
#  'TANH',
#  'ADX',
#  'ADXR',
#  'APO',
#  'AROON',
#  'AROONOSC',
#  'BOP',
#  'CCI',
#  'CMO',
#  'DX',
#  'MACD',
#  'MACDEXT',
#  'MACDFIX',
#  'MFI',
#  'MINUS_DI',
#  'MINUS_DM',
#  'MOM',
#  'PLUS_DI',
#  'PLUS_DM',
#  'PPO',
#  'ROC',
#  'ROCP',
#  'ROCR',
#  'ROCR100',
#  'RSI',
#  'STOCH',
#  'STOCHF',
#  'STOCHRSI',
#  'TRIX',
#  'ULTOSC',
#  'WILLR',
#  'BBANDS',
#  'DEMA',
#  'EMA',
#  'HT_TRENDLINE',
#  'KAMA',
#  'MA',
#  'MAMA',
#  'MAVP',
#  'MIDPOINT',
#  'MIDPRICE',
#  'SAR',
#  'SAREXT',
#  'SMA',
#  'T3',
#  'TEMA',
#  'TRIMA',
#  'WMA',
#  'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
# ...

# %%
talib.get_function_groups()
# Out:
# {'Cycle Indicators': ['HT_DCPERIOD',
#   'HT_DCPHASE',
#   'HT_PHASOR',
#   'HT_SINE',
#   'HT_TRENDMODE'],
#  'Math Operators': ['ADD',
#   'DIV',
#   'MAX',
#   'MAXINDEX',
#   'MIN',
#   'MININDEX',
#   'MINMAX',
#   'MINMAXINDEX',
#   'MULT',
#   'SUB',
#   'SUM'],
#  'Math Transform': ['ACOS',
#   'ASIN',
#   'ATAN',
#   'CEIL',
#   'COS',
#   'COSH',
#   'EXP',
#   'FLOOR',
#   'LN',
#   'LOG10',
#   'SIN',
#   'SINH',
#   'SQRT',
#   'TAN',
#   'TANH'],
#  'Momentum Indicators': ['ADX',
#   'ADXR',
#   'APO',
#   'AROON',
#   'AROONOSC',
#   'BOP',
#   'CCI',
#   'CMO',
#   'DX',
#   'MACD',
#   'MACDEXT',
#   'MACDFIX',
#   'MFI',
#   'MINUS_DI',
#   'MINUS_DM',
#   'MOM',
#   'PLUS_DI',
#   'PLUS_DM',
#   'PPO',
#   'ROC',
#   'ROCP',
#   'ROCR',
#   'ROCR100',
#   'RSI',
#   'STOCH',
#   'STOCHF',
#   'STOCHRSI',
#   'TRIX',
#   'ULTOSC',
#   'WILLR'],
#  'Overlap Studies': ['BBANDS',
#   'DEMA',
#   'EMA',
#   'HT_TRENDLINE',
#   'KAMA',
#   'MA',
#   'MAMA',
#   'MAVP',
# ...

# %%
talib.get_function_groups()['Pattern Recognition']
# Out:
# ['CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
#  'CDL3LINESTRIKE',
#  'CDL3OUTSIDE',
#  'CDL3STARSINSOUTH',
#  'CDL3WHITESOLDIERS',
#  'CDLABANDONEDBABY',
#  'CDLADVANCEBLOCK',
#  'CDLBELTHOLD',
#  'CDLBREAKAWAY',
#  'CDLCLOSINGMARUBOZU',
#  'CDLCONCEALBABYSWALL',
#  'CDLCOUNTERATTACK',
#  'CDLDARKCLOUDCOVER',
#  'CDLDOJI',
#  'CDLDOJISTAR',
#  'CDLDRAGONFLYDOJI',
#  'CDLENGULFING',
#  'CDLEVENINGDOJISTAR',
#  'CDLEVENINGSTAR',
#  'CDLGAPSIDESIDEWHITE',
#  'CDLGRAVESTONEDOJI',
#  'CDLHAMMER',
#  'CDLHANGINGMAN',
#  'CDLHARAMI',
#  'CDLHARAMICROSS',
#  'CDLHIGHWAVE',
#  'CDLHIKKAKE',
#  'CDLHIKKAKEMOD',
#  'CDLHOMINGPIGEON',
#  'CDLIDENTICAL3CROWS',
#  'CDLINNECK',
#  'CDLINVERTEDHAMMER',
#  'CDLKICKING',
#  'CDLKICKINGBYLENGTH',
#  'CDLLADDERBOTTOM',
#  'CDLLONGLEGGEDDOJI',
#  'CDLLONGLINE',
#  'CDLMARUBOZU',
#  'CDLMATCHINGLOW',
#  'CDLMATHOLD',
#  'CDLMORNINGDOJISTAR',
#  'CDLMORNINGSTAR',
#  'CDLONNECK',
#  'CDLPIERCING',
#  'CDLRICKSHAWMAN',
#  'CDLRISEFALL3METHODS',
# ...

# %%
list(talib.get_function_groups().keys())
# Out:
# ['Cycle Indicators',
#  'Math Operators',
#  'Math Transform',
#  'Momentum Indicators',
#  'Overlap Studies',
#  'Pattern Recognition',
#  'Price Transform',
#  'Statistic Functions',
#  'Volatility Indicators',
#  'Volume Indicators']

# %%
talib.AROONOSC(dataset['High'], dataset['Low'],timeperiod=14)
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 45423   -64.285714
# 45424   -64.285714
# 45425   -64.285714
# 45426   -64.285714
# 45427   -64.285714
# Length: 45428, dtype: float64

# %%
aroon=talib.AROONOSC(dataset['High'], dataset['Low'],timeperiod=14)

# %%
aroon
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 45423   -64.285714
# 45424   -64.285714
# 45425   -64.285714
# 45426   -64.285714
# 45427   -64.285714
# Length: 45428, dtype: float64

# %%
dataset['SMA'] = talib.SMA(dataset['Close'], timeperiod=80)
dataset['EMA'] = talib.EMA(dataset['Close'], timeperiod=80)
dataset['MACD'], dataset['MACD_Signal'], dataset['MACD_Hist'] = talib.MACD(dataset['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
dataset['RSI'] = talib.RSI(dataset['Close'], timeperiod=14)
dataset['WMA'] = talib.WMA(dataset['Close'], timeperiod=80)
dataset['WCLPRICE'] = talib.WCLPRICE(dataset['High'], dataset['Low'], dataset['Close'])
dataset['Daily_Return'] = dataset['Close'].pct_change()
dataset['Volatility'] = dataset['Daily_Return'].rolling(window=30).std() * np.sqrt(252)

# %%
stocks = dataset['stock'].unique()
colors = ['blue', 'green', 'red', 'orange', 'purple', 'brown']  
plt.figure(figsize=(14, 7))
for i, stock in enumerate(stocks):
    stock_data = dataset[dataset['stock'] == stock]
    plt.plot(stock_data['Date'], stock_data['Close'], label=f"{stock} Close Price", color=colors[i % len(colors)])
plt.plot(dataset['Date'], dataset['SMA'], label='20-Day SMA')
plt.title('Simple Moving Average (SMA) for Each Stock')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='upper left')
plt.show()

# %%
stocks = dataset['stock'].unique()
colors = ['blue', 'green', 'red', 'orange', 'purple', 'brown'] 
plt.figure(figsize=(14, 7))
for i, stock in enumerate(stocks):
    stock_data = dataset[dataset['stock'] == stock]
    plt.plot(stock_data['Date'], stock_data['Close'], label=f"{stock} Close Price", color=colors[i % len(colors)])
plt.plot(dataset['Date'], dataset['EMA'], label='20-Day EMA')
plt.title('Exponential Moving Average (EMA) for Each Stock')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='upper left')
plt.show()

# %%
stocks = dataset['stock'].unique()
colors = ['blue', 'green', 'red', 'orange', 'purple', 'brown'] 
plt.figure(figsize=(14, 7))
for i, stock in enumerate(stocks):
    stock_data = dataset[dataset['stock'] == stock]
    plt.plot(stock_data['Date'], stock_data['Close'], label=f"{stock} Close Price", color=colors[i % len(colors)])
plt.figure(figsize=(14,7))
plt.plot(dataset['Date'], dataset['MACD'], label='MACD')
plt.title('MACD')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.plot(dataset['Date'], dataset['MACD_Signal'], label='MACD Signal')
plt.title('MACD Signal')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.plot(dataset['Date'], dataset['RSI'], label='RSI')
plt.axhline(70, color='red', linestyle='--', label='Overbought')
plt.axhline(30, color='green', linestyle='--', label='Oversold')
plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.plot(dataset['Date'], dataset['Close'], label='Close Price')
plt.plot(dataset['Date'], dataset['WCLPRICE'], label='Weighted Close Price')
plt.title('Close Price vs Weighted Close Price (WCLPRICE)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
engulfig=talib.CDLENGULFING  
(dataset['Open'], dataset['Low'],dataset['High'], dataset['Close'])
# Out:
# (0          0.128348
#  1          0.122210
#  2          0.113281
#  3          0.115513
#  4          0.118862
#              ...
#  45423    225.419998
#  45424    216.800003
#  45425    221.190002
#  45426    224.899994
#  45427    232.250000
#  Name: Open, Length: 45428, dtype: float64,
#  0          0.128348
#  1          0.121652
#  2          0.112723
#  3          0.115513
#  4          0.118862
#              ...
#  45423    214.710007
#  45424    216.229996
#  45425    215.330002
#  45426    224.699997
#  45427    220.000000
#  Name: Low, Length: 45428, dtype: float64,
#  0          0.128906
#  1          0.122210
#  2          0.113281
#  3          0.116071
#  4          0.119420
#              ...
#  45423    225.990005
#  45424    226.000000
#  45425    222.279999
#  45426    234.270004
#  45427    232.410004
#  Name: High, Length: 45428, dtype: float64,
#  0          0.128348
#  1          0.121652
#  2          0.112723
#  3          0.115513
#  4          0.118862
# ...

# %%
engulfig
# Out:
# <function talib._ta_lib.CDLENGULFING(open, high, low, close)>

# %%
from talib import abstract

# %%
dataset.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock', 'SMA', 'EMA', 'MACD',
#        'MACD_Signal', 'MACD_Hist', 'RSI', 'WMA', 'WCLPRICE', 'Daily_Return',
#        'Volatility'],
#       dtype='object')

# %%
dataset.head(100)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
# ..        ...       ...       ...       ...       ...        ...        ...
# 95 1981-04-30  0.126674  0.127790  0.126674  0.126674   0.097653   12611200
# 96 1981-05-01  0.126674  0.127790  0.126674  0.126674   0.097653   16553600
# 97 1981-05-04  0.126674  0.126674  0.126116  0.126116   0.097223   14448000
# 98 1981-05-05  0.126116  0.126116  0.125558  0.125558   0.096792   17539200
# 99 1981-05-06  0.122768  0.122768  0.122210  0.122210   0.094211   18950400
#
# ...

# %%
dataset.rename(columns={'Open':'open','High':'high','Low':'low','Close':'close','Adj Close':'Adj Close','Volume':'volume'}, inplace=True)
dataset
# Out:
#             Date        open        high         low       close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...          ...         ...         ...         ...         ...         ...
# 45423 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 45424 2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 45425 2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 45426 2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
# 45427 2024-07-30  232.250000  232.410004  220.000000  222.619995  222.619995
#
# ...

# %%
arron_abstract=abstract.AROONOSC(dataset)
arron_abstract
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 45423   -64.285714
# 45424   -64.285714
# 45425   -64.285714
# 45426   -64.285714
# 45427   -64.285714
# Length: 45428, dtype: float64

# %%
arron_abstract=abstract.CDLDOJI(dataset)
arron_abstract
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45423    0
# 45424    0
# 45425    0
# 45426    0
# 45427    0
# Length: 45428, dtype: int32

# %%
import talib
import numpy as np

# Get the function groups from talib
function_groups = talib.get_function_groups()
keys = list(function_groups.keys())

# Print the list of technical indicator types
print('List of technical indicator types: ' + str(np.array(keys)) + "\n")

# Get user input
x = input('Enter tech indicators as match as above: ')

# Check if the input is a valid key
if x in function_groups:
    print("\n", "\n")
    print(function_groups[x])
else:
    print(f"Error: '{x}' is not a valid technical indicator type. Please enter one of the following: {keys}")
# Out:
# List of technical indicator types: ['Cycle Indicators' 'Math Operators' 'Math Transform'
#  'Momentum Indicators' 'Overlap Studies' 'Pattern Recognition'
#  'Price Transform' 'Statistic Functions' 'Volatility Indicators'
#  'Volume Indicators']
#
# Error: '' is not a valid technical indicator type. Please enter one of the following: ['Cycle Indicators', 'Math Operators', 'Math Transform', 'Momentum Indicators', 'Overlap Studies', 'Pattern Recognition', 'Price Transform', 'Statistic Functions', 'Volatility Indicators', 'Volume Indicators']

# %%
dataset['RSI']=abstract.RSI(dataset)
print(dataset)
# Out:
#             Date        open        high         low       close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...          ...         ...         ...         ...         ...         ...
# 45423 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 45424 2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 45425 2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 45426 2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
# 45427 2024-07-30  232.250000  232.410004  220.000000  222.619995  222.619995
#
# ...
